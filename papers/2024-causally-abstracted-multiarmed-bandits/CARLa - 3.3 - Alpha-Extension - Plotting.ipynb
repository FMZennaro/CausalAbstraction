# %%
import os
#os.chdir(os.path.abspath(os.path.pardir))

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib

# %%
avgregrets1 = joblib.load('results/simul_3_1_avgcumregrets.pkl')
avgregrets2 = joblib.load('results/simul_3_2_avgcumregrets.pkl')

# %%
import matplotlib
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 18}

plt.rc('font', **font)

# %%
n_steps = range(len(avgregrets1[0]))
plt.plot(n_steps,avgregrets1[0],label='UCB',linestyle='--',color='b')
plt.plot(n_steps,avgregrets1[1],label='TExp',color='b')

plt.plot(n_steps,avgregrets2[0],label='UCB',linestyle='--',color='g')
plt.plot(n_steps,avgregrets2[1],label='TExp',color='g')


plt.xlabel('T')
plt.ylabel('${\\rho}$')
plt.legend(loc='upper left')
