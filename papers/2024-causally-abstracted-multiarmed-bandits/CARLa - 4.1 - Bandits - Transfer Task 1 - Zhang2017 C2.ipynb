# %% [markdown]
# # CARL Bandits
#
# Using an extension of $\alpha_{Y'}$ to transfer $Q$.

# %% [markdown]
# ## Setup
#
# Let us start by importing a couple of generic libraries.

# %%
import os
os.chdir(os.path.abspath(os.path.pardir))

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib
import ot
from tqdm import tqdm

from src.SCMMappings import Abstraction
from src.measuring import ICEvaluator
from src.examples import smokingmodels as sm
import src.evaluationsets as esets

import src.bandit_envs as BE
import src.bandit_agents as BA
import CARLa_trials as CTr
import CARLa_plots as Cplt
import CARLa_abserr as Cae
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
np.random.seed(0)

# %% [markdown]
# ## Model setup

# %%
from src.CBN import CausalBayesianNetwork as CBN
from pgmpy.factors.discrete import TabularCPD as cpd

# %%
U = 'U'; X='X'; Y='Y'
M0 = CBN([(U,X),(U,Y),(X,Y)])

cpdU = cpd(variable=U,
          variable_card=2,
          values=np.array([[.3],[.7]]),
          evidence=None,
          evidence_card=None)
cpdX = cpd(variable=X,
          variable_card=2,
          values=np.array([[1,.0],[.0,1]]),
          evidence=[U],
          evidence_card=[2])
cpdY = cpd(variable=Y,
          variable_card=2,
          values=np.array([[.9,.5,.1,.7],[.1,.5,.9,.3]]),
          evidence=[U,X],
          evidence_card=[2,2])

M0.add_cpds(cpdU,cpdX,cpdY)
M0.check_model()
# Out:
# True

# %%
U = 'U_'; X='X_'; Y='Y_'
M1 = CBN([(U,Y),(X,Y)])

cpdU = cpd(variable=U,
          variable_card=2,
          values=np.array([[.3],[.7]]),
          evidence=None,
          evidence_card=None)
cpdX = cpd(variable=X,
          variable_card=2,
          values=np.array([[.5],[.5]]),
          evidence=None,
          evidence_card=None)
cpdY = cpd(variable=Y,
          variable_card=2,
          values=np.array([[.9,.5,.1,.7],[.1,.5,.9,.3]]),
          evidence=[U,X],
          evidence_card=[2,2])

M1.add_cpds(cpdU,cpdX,cpdY)
M1.check_model()
# Out:
# True

# %%
R = ['U','X','Y']
a = {'U': 'U_',
    'X': 'X_',
    'Y': 'Y_'}
alphas = {'U_': np.eye(2),
          'X_': np.eye(2),
          'Y_': np.eye(2)}

# %%
map_rewards = {i:np.argmax(alphas['Y_'][:,i]) for i in range(alphas['Y_'].shape[1])}
    
ydomain0 = lambda x:x
ydomain1 = lambda x:x
map_ydomains = {ydomain0(i):ydomain1(j) for i,j in map_rewards.items()}

actions0=[{'X':0}, {'X':1}]
actions1=[{'X_':0}, {'X_':1}]
map_actions = {0: 0, 1: 1}

# %%
def metricW2(p,q):
    Dy1 = np.array([ydomain0(i) for i in map_rewards.values()])
    
    if p.ndim == 1:
        return ot.wasserstein_1d(Dy1,Dy1,p,q,p=2)
    else:
        ws = []
        for i in range(p.shape[1]):
            w = ot.wasserstein_1d(Dy0,Dy1,p[:,i],q[:,i],p=2)
            ws.append(w)
        return ws

# %%
Ab = Abstraction(M0,M1,R,a,alphas)
Ae = ICEvaluator(Ab,metric=metricW2)
J = esets.get_causal_sets_in_M0_with_directed_path_in_M1_and_M0(Ab.M0,Ab.M1,Ab.a)
Ae.compute_overall_error(J)
# Out:
# 0.3

# %% [markdown]
# ## Experiment settings

# %%
params_to_save_start = set(dir())
simulname = 'simul_4_1'

n_trials = 20
n_steps = 500

# %% [markdown]
# ## CAMAB settings

# %% [markdown]
# ### Bandits setting

# %%
B0 = BE.SCMEnv(scm=Ab.M0, actions=actions0, target='Y', ydomain=ydomain0)
B1 = BE.SCMEnv(scm=Ab.M1, actions=actions1, target='Y_', ydomain=ydomain1)

# %% [markdown]
# ### Learning setting

# %%
bandits = [B1,B0,B1,B1,B1,B1]

labels = ['M1: transfer', 'M0: ucb', 'M1: ucb', 'M1: transfer-optimum', 'M1: imitation', 'M1: Qextension']
trainalg = ['ucb_bounds', 'ucb', 'ucb', 'transfer-optimum', 'imitation', 'transfer-expval']
params = {}

# Alg params
params['Qinit'] = [BA.initialize_Q_ones,BA.initialize_Q_ones,BA.initialize_Q_ones,None,BA.initialize_Q_ones,None]
params['Qtransferstep'] = [None,None,None,None,None,-1]
params['abserr'] = [None,None,None,None,None,Ae.compute_overall_error(J)]
params['delta'] = [None,None,None,None,None,0.01]

# UCB params
params['c'] = [1.0] * len(labels)

# %% [markdown]
# ## Statistics settings

# %%
agents = [[] for _ in range(len(labels))]

params_to_save = set(dir()) - params_to_save_start
simulparams = [s for s in params_to_save if s[0]!='_']

# %% [markdown]
# # Transfer Training

# %%
lbounds = [0.03,0.21]
hbounds = [0.73,0.51]

# %%
bounds = [lbounds,hbounds]

# %%
params['bounds'] = [bounds,None,None,None,None,None]

# %%
for t in tqdm(range(n_trials)):
    ag0 = CTr.run_trial(bandits[0],n_steps,trainalg[0],
                        {k: params[k][0] for k in params.keys()},
                        map_actions,map_rewards,map_ydomains)
    agents[0].append(ag0)
# Out:
#   0%|                                                                                                           | 0/20 [00:00<?, ?it/s]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#   5%|████▉                                                                                              | 1/20 [00:02<00:41,  2.17s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  10%|█████████▉                                                                                         | 2/20 [00:05<00:49,  2.74s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  15%|██████████████▊                                                                                    | 3/20 [00:09<00:54,  3.21s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  20%|███████████████████▊                                                                               | 4/20 [00:12<00:54,  3.43s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  25%|████████████████████████▊                                                                          | 5/20 [00:16<00:53,  3.56s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  30%|█████████████████████████████▋                                                                     | 6/20 [00:20<00:51,  3.65s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  35%|██████████████████████████████████▋                                                                | 7/20 [00:24<00:47,  3.68s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  40%|███████████████████████████████████████▌                                                           | 8/20 [00:28<00:44,  3.75s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  45%|████████████████████████████████████████████▌                                                      | 9/20 [00:32<00:42,  3.85s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  50%|█████████████████████████████████████████████████                                                 | 10/20 [00:36<00:39,  3.92s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  55%|█████████████████████████████████████████████████████▉                                            | 11/20 [00:41<00:38,  4.25s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  60%|██████████████████████████████████████████████████████████▊                                       | 12/20 [00:45<00:34,  4.31s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  65%|███████████████████████████████████████████████████████████████▋                                  | 13/20 [00:50<00:31,  4.49s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  70%|████████████████████████████████████████████████████████████████████▌                             | 14/20 [00:56<00:29,  4.91s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  75%|█████████████████████████████████████████████████████████████████████████▌                        | 15/20 [01:01<00:24,  4.81s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  80%|██████████████████████████████████████████████████████████████████████████████▍                   | 16/20 [01:04<00:18,  4.52s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  85%|███████████████████████████████████████████████████████████████████████████████████▎              | 17/20 [01:08<00:12,  4.32s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  90%|████████████████████████████████████████████████████████████████████████████████████████▏         | 18/20 [01:12<00:08,  4.17s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
#  95%|█████████████████████████████████████████████████████████████████████████████████████████████     | 19/20 [01:16<00:04,  4.06s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: divide by zero encountered in log
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in sqrt
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:182: RuntimeWarning: invalid value encountered in divide
#   U = self.Q + self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter )
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [01:20<00:00,  4.01s/it]

# %% [markdown]
# # Abstraction Training

# %%
for t in tqdm(range(n_trials)):
    ag1 = CTr.run_trial(bandits[1],n_steps,trainalg[1],
                        {k: params[k][1] for k in params.keys()},
                        map_actions,map_rewards,map_ydomains)
    agents[1].append(ag1)
    
    for i in range(2,len(labels)):
        ag = CTr.run_trial(bandits[i],n_steps,trainalg[i],
                           {k: params[k][i] for k in params.keys()},
                            map_actions,map_rewards,map_ydomains,base_bandit=ag1)
        agents[i].append(ag)
# Out:
#   0%|                                                                                                           | 0/20 [00:00<?, ?it/s]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#   5%|████▉                                                                                              | 1/20 [00:19<06:07, 19.33s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  10%|█████████▉                                                                                         | 2/20 [00:38<05:42, 19.04s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  15%|██████████████▊                                                                                    | 3/20 [00:56<05:21, 18.90s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  20%|███████████████████▊                                                                               | 4/20 [01:15<05:02, 18.89s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  25%|████████████████████████▊                                                                          | 5/20 [01:34<04:44, 18.94s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  30%|█████████████████████████████▋                                                                     | 6/20 [01:53<04:24, 18.92s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  35%|██████████████████████████████████▋                                                                | 7/20 [02:13<04:08, 19.13s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  40%|███████████████████████████████████████▌                                                           | 8/20 [02:32<03:51, 19.28s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  45%|████████████████████████████████████████████▌                                                      | 9/20 [02:52<03:34, 19.46s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  50%|█████████████████████████████████████████████████                                                 | 10/20 [03:12<03:14, 19.48s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  55%|█████████████████████████████████████████████████████▉                                            | 11/20 [03:31<02:55, 19.52s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  60%|██████████████████████████████████████████████████████████▊                                       | 12/20 [03:51<02:35, 19.50s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  65%|███████████████████████████████████████████████████████████████▋                                  | 13/20 [04:10<02:16, 19.54s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  70%|████████████████████████████████████████████████████████████████████▌                             | 14/20 [04:30<01:57, 19.51s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  75%|█████████████████████████████████████████████████████████████████████████▌                        | 15/20 [04:49<01:37, 19.46s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  80%|██████████████████████████████████████████████████████████████████████████████▍                   | 16/20 [05:10<01:18, 19.75s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  85%|███████████████████████████████████████████████████████████████████████████████████▎              | 17/20 [05:31<01:00, 20.30s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  90%|████████████████████████████████████████████████████████████████████████████████████████▏         | 18/20 [05:57<00:43, 21.90s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
#  95%|█████████████████████████████████████████████████████████████████████████████████████████████     | 19/20 [06:20<00:22, 22.15s/it]C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: divide by zero encountered in log
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in sqrt
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# C:\Users\admin\gits\scratchbook\CausalAbstraction\src\bandit_agents.py:146: RuntimeWarning: invalid value encountered in divide
#   U = self.c * np.sqrt( np.log(np.sum(self.action_counter)) / self.action_counter  )
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [06:39<00:00, 19.99s/it]

# %% [markdown]
# # Persistence

# %%
stats = {simulparams[i]: eval(simulparams[i]) for i in range(len(simulparams))}

# %% [raw]
# joblib.dump(stats,'results/{0}.pkl'.format(simulname))

# %% [markdown]
# # Evaluation of the results

# %%
from collections import OrderedDict

linestyles = OrderedDict(
    [('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))])

import matplotlib
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 18}

plt.rc('font', **font)

# %%
style = ['-','--',':','-.',linestyles['dashdotdotted']]
for n,i in enumerate([0,2,3,4,5]):
    cumregrets = [agents[i][j].get_cumulative_regret() for j in range(len(agents[i]))]
    avg = np.mean(cumregrets,axis=0)
    std = np.std(cumregrets,axis=0)

    plt.plot(np.arange(n_steps),avg,label=labels[i],color="C{}".format(i),linestyle=style[n])
    plt.fill_between(np.arange(n_steps),avg+std,avg-std, color='C{}'.format(i), alpha=0.2)
    plt.xlabel('Steps')
    plt.ylabel('Cumulative regret')
    plt.legend(loc='upper left')
    plt.ylim([-10,50])

# %%
style = ['-','--',':','-.',linestyles['dashdotdotted']]
for n,i in enumerate([0,2,3,4,5]):
    cumregrets = [agents[i][j].get_cumulative_regret() for j in range(len(agents[i]))]
    avg = np.mean(cumregrets,axis=0)

    plt.plot(np.arange(n_steps)[0::100],avg[0::100],label=labels[i],color="C{}".format(i),linestyle=style[n])
    plt.xlabel('Steps')
    plt.ylabel('Cumulative regret')
    plt.legend(loc='upper left')
    plt.ylim([-10,50])

# %% [markdown]
# ### Plot data persistence

# %%
avgcumregrets = []
for i in [0,1,2,3,4,5]:
    cumregrets = np.array([agents[i][j].get_cumulative_regret() for j in range(n_trials)])
    avgcumregrets.append(np.mean(cumregrets,axis=0))
joblib.dump(avgcumregrets,'proj CARLa 3_0/results/simul_4_1_avgcumregrets.pkl')
# Out:
# ['proj CARLa 3_0/results/simul_4_1_avgcumregrets.pkl']

# %%
agents[0][1].bounds
# Out:
# [[0.03, 0.21], [0.73, 0.51]]

# %%
agents[5][2].bounds
# Out:
# [[0.20425121429207083, -0.23099626921975663],
#  [1.1167649519896852, 1.1703902086136961]]

# %%
agents[5][2].env.expct_rewards
# Out:
# [0.66, 0.36000000000000004]
