# %%
import os
os.chdir(os.path.abspath(os.path.pardir))

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib

# %%
avgregrets = joblib.load('proj CARLa 2_0/results/simul_5_1_avgcumregrets.pkl')

# %%
import matplotlib
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 18}

plt.rc('font', **font)

# %%
n_steps = range(len(avgregrets[0]))
plt.plot(n_steps,avgregrets[0],label='UCB',linestyle=':',color='b')
plt.plot(n_steps,avgregrets[1],label='TOpt',linestyle='-.',color='g')
plt.plot(n_steps,avgregrets[2],label='IMIT',linestyle='--',color='r')
plt.plot(n_steps,avgregrets[3],label='TExp',linestyle='-',color='y')

plt.xlabel('T')
plt.ylabel('${\\rho}$')
plt.legend()
