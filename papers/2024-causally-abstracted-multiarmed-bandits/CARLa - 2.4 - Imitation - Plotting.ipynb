# %%
import os
os.chdir(os.path.abspath(os.path.pardir))

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib

# %%
avgdiffregrets1 = joblib.load('proj CARLa 3_0/results/simul_2_3_diffcumregrets_agentA.pkl')
avgdiffregrets2 = joblib.load('proj CARLa 3_0/results/simul_2_3_diffcumregrets_agentB.pkl')

# %%
import matplotlib
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 18}

plt.rc('font', **font)

# %%
n_steps = range(len(avgdiffregrets1))
plt.plot(n_steps,avgdiffregrets1,label='$\\alpha_1$',color='b')
plt.plot(n_steps,avgdiffregrets2,label='$\\alpha_2$',color='r')
plt.legend

plt.xlabel('T')
plt.ylabel('$\\rho_{UCB} - \\rho_{\mathtt{IMIT}}$')
plt.legend(loc='lower left')
